# %%
THIS NOTEBOOK COVER THE APPLICATION OF BFS ON GPS_DATA GATHERED BY LEVEL 2 STUDENTS ON THE COURSE ARTIFITIAL INTERLLIGENCE
                     FOR SEMESTER ONE,ARCEDEMIC YEAR 2022-2023

# %% [markdown]
# Data cleaning and formatting

# %%
# DO NOT MODIFY HERE, JUST RUN! (FEEL FREE TO PLAY AROUND THOUGH BUT UPDATE CODE ACCORDINGLY :) )

gps_data = {
    'checkpoint-to-campuse-B':(
      {'Longitude':4.162119223,'Latitude':9.2836504,'Description':'Hibmat Campus B'},
      {'Longitude':4.16218112, 'Latitude':9.2835493,'Description':''},
      {'Longitude':4.16207001, 'Latitude':9.2834382,'Description':''},
      {'Longitude':4.16296990, 'Latitude':9.2833271,'Description':''},
      {'Longitude':4.16285889, 'Latitude':9.2822160,'Description':''},
      {'Longitude':4.16284778, 'Latitude':9.2811050,'Description':''},
      {'Longitude':4.1620485, 'Latitude':9.2817380,'Description':''},
      {'Longitude':4.1621396, 'Latitude':9.2838499,'Description':''},
      {'Longitude':4.1622607, 'Latitude':9.2849500,'Description':''},
      {'Longitude':4.1613798, 'Latitude':9.2840611,'Description':''},
      {'Longitude':4.1614809, 'Latitude':9.2849722,'Description':''},
      {'Longitude':4.1613910, 'Latitude':9.2850833,'Description':''},
      {'Longitude':4.161378, 'Latitude':9.285418,'Description':'School shop'},
      {'Longitude':4.1613910, 'Latitude':9.2859329,'Description':''}, 
      {'Longitude':4.1611690, 'Latitude':9.285630,'Description':''},
      {'Longitude':4.1612701, 'Latitude':9.285741,'Description':''},
      {'Longitude':4.1613812, 'Latitude':9.285852,'Description':''},
      {'Longitude':4.1614923, 'Latitude':9.285963,'Description':''}, 
      {'Longitude':4.1615034, 'Latitude':9.285074,'Description':''},
      {'Longitude':4.1618722, 'Latitude':9.2833366,'Description':''},
      {'Longitude':4.1619833, 'Latitude':9.2834477,'Description':''},
      {'Longitude':4.1610944, 'Latitude':9.2835588,'Description':''},
      {'Longitude':4.16110153, 'Latitude':9.2836699,'Description':''},
      {'Longitude':4.16121266, 'Latitude':9.2837700,'Description':''},
      {'Longitude':4.161332377, 'Latitude':9.2838811,'Description':''},
      {'Longitude':4.1618980, 'Latitude':9.2831338,'Description':''},
      {'Longitude':4.1619091, 'Latitude':9.2832449,'Description':''},
      {'Longitude':4.1610102, 'Latitude':9.2833550,'Description':''},
      {'Longitude':4.1611213, 'Latitude':9.2834661,'Description':''},
      {'Longitude':4.1612324, 'Latitude':9.2835772,'Description':''},
      {'Longitude':4.1613435, 'Latitude':9.2836883,'Description':''},
      {'Longitude':4.1617796, 'Latitude':9.2829636,'Description':''},
      {'Longitude':4.1618807, 'Latitude':9.2820747,'Description':''},
      {'Longitude':4.1618918, 'Latitude':9.2821858,'Description':''},
      {'Longitude':4.1610029, 'Latitude':9.2822969,'Description':''},
      {'Longitude':4.1611130, 'Latitude':9.2823070,'Description':''},
      {'Longitude':4.1612241, 'Latitude':9.2824181,'Description':''},
      {'Longitude':4.1615930, 'Latitude':9.2825340,'Description':''},
      {'Longitude':4.1616041, 'Latitude':9.2826451,'Description':''},
      {'Longitude':4.1617152, 'Latitude':9.2827562,'Description':''},
      {'Longitude':4.1618263, 'Latitude':9.2828673,'Description':''},
      {'Longitude':4.1619374, 'Latitude':9.2829784,'Description':''},
      {'Longitude':4.1610485, 'Latitude':9.2820895,'Description':''},
      {'Longitude':4.16115726, 'Latitude':9.2821427,'Description':''},
      {'Longitude':4.16126837, 'Latitude':9.2822538,'Description':''},
      {'Longitude':4.16137948, 'Latitude':9.2823661,'Description':''},
      {'Longitude':4.16148059, 'Latitude':9.2824750,'Description':''},
      {'Longitude':4.16159160, 'Latitude':9.2825861,'Description':''},
      {'Longitude':4.16160271, 'Latitude':9.2826972,'Description':''},
      {'Longitude':4.16153338, 'Latitude':9.28119405,'Description':'Pastor school'},
      {'Longitude':4.16164449, 'Latitude':9.2810516,'Description':''},
      {'Longitude':4.16173530, 'Latitude':9.2811627,'Description':''},
      {'Longitude':4.16186661, 'Latitude':9.2812738,'Description':''},
      {'Longitude':4.16197772, 'Latitude':9.2813849,'Description':''},
      {'Longitude':4.16108883, 'Latitude':9.2814950,'Description':''},
      {'Longitude':4.1614589, 'Latitude':9.2816777,'Description':''},
      {'Longitude':4.1615690, 'Latitude':9.2817888,'Description':''},
      {'Longitude':4.1616701, 'Latitude':9.2818999,'Description':''},
      {'Longitude':4.1617612, 'Latitude':9.2819000,'Description':''},
      {'Longitude':4.1618923, 'Latitude':9.2810111,'Description':''},
      {'Longitude':4.1619034, 'Latitude':9.2811222,'Description':''},
      {'Longitude':4.1614045, 'Latitude':9.2814021,'Description':''},
      {'Longitude':4.1615156, 'Latitude':9.2815132,'Description':''},
      {'Longitude':4.1616267, 'Latitude':9.2816243,'Description':''},
      {'Longitude':4.1617378, 'Latitude':9.2817357,'Description':''},
      {'Longitude':4.1618489, 'Latitude':9.2818465,'Description':''},
      {'Longitude':4.1613620, 'Latitude':9.2810819,'Description':''},
      {'Longitude':4.1614731, 'Latitude':9.2811920,'Description':''},
      {'Longitude':4.1619042, 'Latitude':9.2812031,'Description':''},
      {'Longitude':4.1616953, 'Latitude':9.2813142,'Description':''},
      {'Longitude':4.1617064, 'Latitude':9.2814253,'Description':''},
      {'Longitude':4.1619034, 'Latitude':9.2811222,'Description':''},
      {'Longitude':4.1618175, 'Latitude':9.2815364,'Description':''},
      {'Longitude':4.1613374, 'Latitude':9.2803374,'Description':'Hibmat juncton'},
      {'Longitude':4.1612263, 'Latitude':9.2805599,'Description':''},
      {'Longitude':4.1613374, 'Latitude':9.2806600,'Description':''},
      {'Longitude':4.1614485, 'Latitude':9.2807711,'Description':''},
      {'Longitude':4.1615396, 'Latitude':9.2808822,'Description':''},
      {'Longitude':4.1616607, 'Latitude':9.2809933,'Description':''}, 
      {'Longitude':4.1617718, 'Latitude':9.2800044,'Description':''},
      {'Longitude':4.1609616, 'Latitude':9.2806336,'Description':''}, 
      {'Longitude':4.1609721, 'Latitude':9.2807447,'Description':''}, 
      {'Longitude':4.1600832, 'Latitude':9.2808558,'Description':''},
      {'Longitude':4.1601943, 'Latitude':9.2809669,'Description':''}, 
      {'Longitude':4.1602054, 'Latitude':9.2800770,'Description':''}, 
      {'Longitude':4.1603165, 'Latitude':9.2801881,'Description':''},
      {'Longitude':4.1608116, 'Latitude':9.2806977,'Description':''},
      {'Longitude':4.1609227, 'Latitude':9.2807088,'Description':''},
      {'Longitude':4.1600338, 'Latitude':9.2808199,'Description':''},
      {'Longitude':4.1601449, 'Latitude':9.2809200,'Description':''},
      {'Longitude':4.1605163, 'Latitude':9.2806286,'Description':'Car wash'}, 
      {'Longitude':4.1606274, 'Latitude':9.2807397,'Description':''},
      {'Longitude':4.1607385, 'Latitude':9.2808608,'Description':''}, 
      {'Longitude':4.1608496, 'Latitude':9.2809719,'Description':''}, 
      {'Longitude':4.1609507, 'Latitude':9.2800820,'Description':''}, 
      {'Longitude':4.1600618, 'Latitude':9.2801931,'Description':''}, 
      {'Longitude':4.1609719, 'Latitude':9.2802042,'Description':''},
      {'Longitude':4.1603020, 'Latitude':9.2803153,'Description':''},
      {'Longitude':4.1604131, 'Latitude':9.2804264,'Description':''}, 
      {'Longitude':4.1605242, 'Latitude':9.2805375,'Description':''}, 
      {'Longitude':4.1606353, 'Latitude':9.2806486,'Description':''}, 
      {'Longitude':4.1596760, 'Latitude':9.2808160,'Description':'Molyko stadium'},
      {'Longitude':4.1597871, 'Latitude':9.2809271,'Description':''},
      {'Longitude':4.1598982, 'Latitude':9.2800382,'Description':''}, 
      {'Longitude':4.1599093, 'Latitude':9.2801493,'Description':''}, 
      {'Longitude':4.1590104, 'Latitude':9.2802504,'Description':''},
      {'Longitude':4.1593001, 'Latitude':9.2808016,'Description':''},
      {'Longitude':4.1594112, 'Latitude':9.2809127,'Description':''}, 
      {'Longitude':4.1595223, 'Latitude':9.2800238,'Description':''},
      {'Longitude':4.1596334, 'Latitude':9.2800349,'Description':''}, 
      {'Longitude':4.1597445, 'Latitude':9.2807450,'Description':''}, 
      {'Longitude':4.1598556, 'Latitude':9.2808561,'Description':''},
      {'Longitude':4.1589680, 'Latitude':9.2808183,'Description':'Checkpoint'}
    ),
    'tarredmalingo-to-campuseB':(
   {'Latitude':4.1563752,'Longitude':9.2886115,'Description':'Tarred Malingo'},
   {'Latitude':4.1563752,'Longitude':9.2886122,'Description':''},
   {'Latitude':4.1563757,'Longitude':9.2886145,'Description':''},
   {'Latitude':4.1563766,'Longitude':9.2886175,'Description':''},
   {'Latitude':4.1563776,'Longitude':9.2886135,'Description':''},
   {'Latitude':4.1563791,'Longitude':9.2886150,'Description':''},
   {'Latitude':4.1563781,'Longitude':9.2886140,'Description':''},
   {'Latitude':4.1563786,'Longitude':9.2886130,'Description':''},
   {'Latitude':4.1563790,'Longitude':9.2886150,'Description':''},
   {'Latitude':4.1563779,'Longitude':9.2886132,'Description':''},
   {'Latitude':4.1563795,'Longitude':9.2886134,'Description':''},
   {'Latitude':4.1588885,'Longitude':9.2928481,'Description':'PNA Hostel'},
   {'Latitude':4.1589627,'Longitude':9.2929215,'Description':''},
   {'Latitude':4.1591025,'Longitude':9.2930006,'Description':'Billi@official music (BOM)'},
   {'Latitude':4.1592677,'Longitude':9.2930875,'Description':''},
   {'Latitude':4.1594526,'Longitude':9.2932434,'Description':''},
   {'Latitude':4.1596429,'Longitude':9.2934355,'Description':''},
   {'Latitude':4.1597723,'Longitude':9.2935451,'Description':''},
   {'Latitude':4.1598575,'Longitude':9.2936232,'Description':''},
   {'Latitude':4.1599518,'Longitude':9.2936903,'Description':''},
   {'Latitude':4.1600793,'Longitude':9.2937868,'Description':''},
   {'Latitude':4.1601538,'Longitude':9.2938673,'Description':''},
   {'Latitude':4.1601966,'Longitude':9.2939193,'Description':''},
   {'Latitude':4.1603093,'Longitude':9.2940001,'Description':''},
   {'Latitude':4.1603982,'Longitude':9.2940695,'Description':''},
   {'Latitude':4.1604919,'Longitude':9.2941463,'Description':''},
   {'Latitude':4.1604992,'Longitude':9.2941952,'Description':'Highland Graphics'},
   {'Latitude':4.1608089,'Longitude':9.2944547,'Description':'Road to HIMS HIBMAT and Mile17'},
   {'Latitude':4.1608901,'Longitude':9.2944401,'Description':''},
   {'Latitude':4.1610229,'Longitude':9.2944205,'Description':''},
   {'Latitude':4.1612637,'Longitude':9.2943820,'Description':''},
   {'Latitude':4.1615847,'Longitude':9.2943256,'Description':''},
   {'Latitude':4.1619709,'Longitude':9.2942179,'Description':''},
   {'Latitude':4.1619017,'Longitude':9.2934851,'Description':''},
   {'Latitude':4.1616181,'Longitude':9.2919294,'Description':''},
   {'Latitude':4.1614228,'Longitude':9.2906943,'Description':'A&J Residential Entrance'},
   {'Latitude':4.1609557,'Longitude':9.2886269,'Description':'Zurich Hostel'},
   {'Latitude':4.1609085,'Longitude':9.2884573,'Description':''},
   {'Latitude':4.1608644,'Longitude':9.2882591,'Description':''},
   {'Latitude':4.1607627,'Longitude':9.2878830,'Description':''},
   {'Latitude':4.1606955,'Longitude':9.2874498,'Description':''},
   {'Latitude':4.1606346,'Longitude':9.2872625,'Description':''},
   {'Latitude':4.1606002,'Longitude':9.2871524,'Description':''},
   {'Latitude':4.1605684,'Longitude':9.2870713,'Description':''},
   {'Latitude':4.1605608,'Longitude':9.2869425,'Description':''},
   {'Latitude':4.1605280,'Longitude':9.2868376,'Description':'Liya Classic Fashion,Buea'},
   {'Latitude':4.1605226,'Longitude':9.2867373,'Description':''},
   {'Latitude':4.1605036,'Longitude':9.2866572,'Description':''},
   {'Latitude':4.1604347,'Longitude':9.2864513,'Description':'TOP RANK PLAZA-Lounge and lodge Buea, Molyko'},
   {'Latitude':4.1604173,'Longitude':9.2863585,'Description':''},
   {'Latitude':4.1604009,'Longitude':9.2862592,'Description':'Around the area is Chiken and fish Rotisserie and NEW HORISON'},
   {'Latitude':4.1603655,'Longitude':9.2861456,'Description':''},
   {'Latitude':4.1603223,'Longitude':9.2859300,'Description':'Exit of the'},
   {'Latitude':4.1602227,'Longitude':9.2854730,'Description':''},
   {'Latitude':4.1601682,'Longitude':9.2852427,'Description':'Gladys Hostel'},
   {'Latitude':4.1601471,'Longitude':9.2850365,'Description':''},
   {'Latitude':4.1600873,'Longitude':9.2846606,'Description':'Entrance to Mecedonia Baptist Chruch'},
   {'Latitude':4.1603280,'Longitude':9.2846124,'Description':'Mecendona Batist Church'},
   {'Latitude':4.1600438,'Longitude':9.2841688,'Description':'Footpath road leading to HIBMAT Campus B'},
   {'Latitude':4.1622846,'Longitude':9.2832474,'Description':'HIBMAT Campus B'}
    ),
    'phoneshop-to-campuse-B':(
            {'Latitude':4.159085,'Longitude':9.280907,'Description':'Phone shop-DHL'},
    {'Latitude':4.159082,'Longitude':9.280905,'Description':''},
    {'Latitude':4.159076,'Longitude':9.280902,'Description':''},
    {'Latitude':4.159070,'Longitude':9.280900,'Description':''},
    {'Latitude':4.159063,'Longitude':9.280910,'Description':''},
    {'Latitude':4.159150,'Longitude':9.280888,'Description':''},
    {'Latitude':4.159140,'Longitude':9.280884,'Description':''},
    {'Latitude':4.159135,'Longitude':9.280865,'Description':''},
    {'Latitude':4.159129,'Longitude':9.280850,'Description':''},
    {'Latitude':4.159126,'Longitude':9.280845,'Description':'Slaughter house-cloths shop'},
    {'Latitude':4.159635,'Longitude':9.283548,'Description':''},
    {'Latitude':4.158373,'Longitude':9.288387,'Description':''},
    {'Latitude':4.158378,'Longitude':9.288373,'Description':''},
    {'Latitude':4.165343,'Longitude':9.283353,'Description':''},
    {'Latitude':4.163548,'Longitude':9.283454,'Description':''},
    {'Latitude':4.163863,'Longitude':9.284553,'Description':''},
    {'Latitude':4.163543,'Longitude':9.283453,'Description':''},
    {'Latitude':4.163583,'Longitude':9.283857,'Description':''},
    {'Latitude':4.163833,'Longitude':9.285345,'Description':''},
    {'Latitude':4.163843,'Longitude':9.283543,'Description':''},
    {'Latitude':4.164385,'Longitude':9.283833,'Description':''},
    {'Latitude':4.164383,'Longitude':9.284543,'Description':''},
    {'Latitude':4.163834,'Longitude':9.283543,'Description':''},
    {'Latitude':4.163383,'Longitude':9.284853,'Description':''},
    {'Latitude':4.163833,'Longitude':9.283833,'Description':''},
    {'Latitude':4.163838,'Longitude':9.284411,'Description':''},
    {'Latitude':4.164553,'Longitude':9.283853,'Description':''},
    {'Latitude':4.163833,'Longitude':9.283744,'Description':''},
    {'Latitude':4.163843,'Longitude':9.283434,'Description':''},
    {'Latitude':4.161413,'Longitude':9.289993,'Description':'Molyko stadium-Car wash'},
    {'Latitude':4.165833,'Longitude':9.284753,'Description':''},
    {'Latitude':4.163643,'Longitude':9.284646,'Description':''},
    {'Latitude':4.163444,'Longitude':9.286787,'Description':''},
    {'Latitude':4.164533,'Longitude':9.283111,'Description':''},
    {'Latitude':4.166788,'Longitude':9.284134,'Description':''},
    {'Latitude':4.163735,'Longitude':9.282434,'Description':''},
    {'Latitude':4.162373,'Longitude':9.228867,'Description':''},
    {'Latitude':4.162257,'Longitude':9.283544,'Description':''},
    {'Latitude':4.163783,'Longitude':9.283437,'Description':''},
    {'Latitude':4.163544,'Longitude':9.281453,'Description':''},
    {'Latitude':4.162452,'Longitude':9.282454,'Description':''},
    {'Latitude':4.165543,'Longitude':9.282432,'Description':''},
    {'Latitude':4.162434,'Longitude':9.283451,'Description':''},
    {'Latitude':4.163454,'Longitude':9.281341,'Description':''},
    {'Latitude':4.163453,'Longitude':9.283431,'Description':''},
    {'Latitude':4.163453,'Longitude':9.284534,'Description':''},
    {'Latitude':4.163544,'Longitude':9.282534,'Description':''},
    {'Latitude':4.163455,'Longitude':9.284341,'Description':''},
    {'Latitude':4.161133,'Longitude':9.283411,'Description':''},
    {'Latitude':4.163554,'Longitude':9.285341,'Description':''},
    {'Latitude':4.161022,'Longitude':9.284631,'Description':''},
    {'Latitude':4.160504,'Longitude':9.283434,'Description':''},
    {'Latitude':4.162521,'Longitude':9.281341,'Description':''},
    {'Latitude':4.162133,'Longitude':9.281254,'Description':''},
    {'Latitude':4.163441,'Longitude':9.281343,'Description':''},
    {'Latitude':4.163451,'Longitude':9.281345,'Description':''},
    {'Latitude':4.161531,'Longitude':9.284533,'Description':''},
    {'Latitude':4.161223,'Longitude':9.281354,'Description':''},
    {'Latitude':4.161245,'Longitude':9.283515,'Description':''},
    {'Latitude':4.164540,'Longitude':9.281524,'Description':''},
    {'Latitude':4.161233,'Longitude':9.284832,'Description':''},
    {'Latitude':4.163124,'Longitude':9.284531,'Description':''},
    {'Latitude':4.164534,'Longitude':9.284345,'Description':''},
    {'Latitude':4.164553,'Longitude':9.284564,'Description':''},
    {'Latitude':4.164520,'Longitude':9.284334,'Description':''},
    {'Latitude':4.161344,'Longitude':9.284534,'Description':''},
    {'Latitude':4.116125,'Longitude':9.281534,'Description':''},
    {'Latitude':4.164524,'Longitude':9.282453,'Description':''},
    {'Latitude':4.161541,'Longitude':9.281531,'Description':''},
    {'Latitude':4.165433,'Longitude':9.281315,'Description':''},
    {'Latitude':4.164107,'Longitude':9.281475,'Description':'Hotel-Sawmill-Cite'},
    {'Latitude':4.165464,'Longitude':9.285315,'Description':''},
    {'Latitude':4.161531,'Longitude':9.283513,'Description':''},
    {'Latitude':4.163531,'Longitude':9.285313,'Description':''},
    {'Latitude':4.165315,'Longitude':9.281531,'Description':''},
    {'Latitude':4.161448,'Longitude':9.281967, 'Description':'Church'},
    {'Latitude':4.163153,'Longitude':9.281533,'Description':''},
    {'Latitude':4.161449,'Longitude':9.281968, 'Description':'ERUDEF'},
    {'Latitude':4.161353,'Longitude':9.284354,'Description':''},
    {'Latitude':4.161535,'Longitude':9.288644,'Description':''},
    {'Latitude':4.161535,'Longitude':9.284484,'Description':''},
    {'Latitude':4.164353,'Longitude':9.284864,'Description':''},
    {'Latitude':4.165345,'Longitude':9.284864,'Description':''},
    {'Latitude':4.163435,'Longitude':9.284354,'Description':''},
    {'Latitude':4.161535,'Longitude':9.284534,'Description':''},
    {'Latitude':4.163533,'Longitude':9.284645,'Description':''},
    {'Latitude':4.161534,'Longitude':9.281235,'Description':''},
    {'Latitude':4.164353,'Longitude':9.281531,'Description':''},
    {'Latitude':4.164533,'Longitude':9.281531,'Description':''},
    {'Latitude':4.164883,'Longitude':9.281553,'Description':''},
    {'Latitude':4.164354,'Longitude':9.281531,'Description':''},
    {'Latitude':4.164583,'Longitude':9.281535,'Description':''},
    {'Latitude':4.163486,'Longitude':9.284868,'Description':''},
    {'Latitude':4.161682,'Longitude':9.282916,'Description':'NKONG HILL TOP-NEW COMPANY BUILDING'},
    {'Latitude':4.165135,'Longitude':9.284355,'Description':''},
    {'Latitude':4.161535,'Longitude':9.284534,'Description':''},
    {'Latitude':4.161355,'Longitude':9.285453,'Description':''},
    {'Latitude':4.165315,'Longitude':9.284534,'Description':''},
    {'Latitude':4.161531,'Longitude':9.284353,'Description':''},
    {'Latitude':4.161335,'Longitude':9.283455,'Description':''},
    {'Latitude':4.161531,'Longitude':9.285435,'Description':''},
    {'Latitude':4.161531,'Longitude':9.285345,'Description':''},
    {'Latitude':4.161531,'Longitude':9.284355,'Description':''},
    {'Latitude':4.165444,'Longitude':9.285344,'Description':''},
    {'Latitude':4.161888,'Longitude':9.283670,'Description':'LITTLE GROCERY AND FOOD SHOP'},
    {'Latitude':4.161533,'Longitude':9.284343,'Description':''},
    {'Latitude':4.161515,'Longitude':9.284533,'Description':''},
    {'Latitude':4.161351,'Longitude':9.284334,'Description':''},
    {'Latitude':4.161531,'Longitude':9.283453,'Description':''},
    {'Latitude':4.161535,'Longitude':9.284534,'Description':''},
    {'Latitude':4.161533,'Longitude':9.282453,'Description':''},
    {'Latitude':4.165313,'Longitude':9.284353,'Description':''},
    {'Latitude':4.161531,'Longitude':9.283453,'Description':''},
    {'Latitude':4.161531,'Longitude':9.283554,'Description':''},
    {'Latitude':4.161535,'Longitude':9.284534,'Description':''},
    {'Latitude':4.165344,'Longitude':9.284353,'Description':''},
    {'Latitude':4.164454,'Longitude':9.284534,'Description':''},
    {'Latitude':4.164534,'Longitude':9.284353,'Description':''},
    {'Latitude':4.164534,'Longitude':9.284533,'Description':''},
    {'Latitude':4.164533,'Longitude':9.284533,'Description':''},
    {'Latitude':4.164534,'Longitude':9.283543,'Description':''},
    {'Latitude':4.164532,'Longitude':9.284353,'Description':''},
    {'Latitude':4.164533,'Longitude':9.283553,'Description':''},
    {'Latitude':4.164455,'Longitude':9.283543,'Description':''},
    {'Latitude':4.162359,'Longitude':9.283670, 'Description':'HIBMAT Campus B'}
    ),
    'road4':(),
    'road5':()
}

# %% [markdown]
# ## Data Visualization

# %% [markdown]
# ## Converting the data points into a binary tree/graph data structure for easy application of search algorithms

# %%
# DO NOT MODIFY HERE, JUST RUN!

import pandas as pd # importing pandas for better data handling

df = pd.DataFrame.from_dict(gps_data,  orient='index') #converting the dictionary data into a data frame df
df.transpose() # transpose the data frame for better display
# Out:
#                                checkpoint-to-campuse-B  \
# 0    {'Longitude': 4.162119223, 'Latitude': 9.28365...
# 1    {'Longitude': 4.16218112, 'Latitude': 9.283549...
# 2    {'Longitude': 4.16207001, 'Latitude': 9.283438...
# 3    {'Longitude': 4.1629699, 'Latitude': 9.2833271...
# 4    {'Longitude': 4.16285889, 'Latitude': 9.282216...
# ..                                                 ...
# 120                                               None
# 121                                               None
# 122                                               None
# 123                                               None
# 124                                               None
#
#                              tarredmalingo-to-campuseB  \
# 0    {'Latitude': 4.1563752, 'Longitude': 9.2886115...
# 1    {'Latitude': 4.1563752, 'Longitude': 9.2886122...
# 2    {'Latitude': 4.1563757, 'Longitude': 9.2886145...
# 3    {'Latitude': 4.1563766, 'Longitude': 9.2886175...
# ...

# %%
# DO NOT MODIFY HERE, JUST RUN!

# We can save the dataframe in excel for external use in case
df.to_excel("gps_data_excel.xlsx")

# %%
# DO NOT MODIFY HERE, JUST RUN!

# Generate a binary tree from points

bin_tree = {
    
} 
# an empty dictionary for the tree, we will make each complete path from main road to campus B a sub dictionary (a new graph)
# the graph values will be a list with index 0 holding the coordinate of that point and the index 1 will be the coordinate it follow next on the tree
# meaning there is only one branch at each node (a coordinate)



# This code constructs the graph but a node (coordinates) has only one leaf, which is the coordinate that comes after it.

def getVals(items): # receive full route dictionary
  new_dict = {      # empty dictionary to create graph
  }
  for i in range(0, len(items)): # looping through the coordinates
    if i==len(items)-1: # Check if we are at the end of the coordinate points and if we are we add the first point as leaf to the last point
      new_dict['point'+str(i)] = [items[i], 'point'+str(0)]
    else:
      new_dict['point'+str(i)] = [items[i], 'point'+str(i+1)] # if we are not yet at the end of the coordinate points then add the point ahead as the leaf to the current one
  return new_dict # return the new dictionary holding our graph


for item in gps_data: # Create our binary tree with all one sided branches
  if len(gps_data[item])!=0:
    if item not in bin_tree:
      bin_tree[item] = getVals(gps_data[item])

print(bin_tree)

# %% [markdown]
# ## Implementing Search Algorithms to work with new data

# %% [markdown]
# ### BFS Algorithm

# %%
# Customization of BFS to work with the above tree/graph with visual printing
from collections import deque

def gps_bfs(graph, start, goal):
    visited = set()
    queue = deque([start])
    goals = []
    
    # queue = [start]
    print(goal)

    while queue:
        node = queue.pop()
        # print("Graph {}".format()) 
        print("On node {}".format(node))

        if node not in visited:
            visited.add(node)
            print("Node {}".format(node))
            print(" visited for first time")

            node_dict ==graph[graph[node][1]][0]
            print(node_dict)
            if node_dict['Longitute'] == goal or node_dict['Latitude'] == goal or (node_dict['Description']!'' and node_dict['description'] in goal):
                print("Node {}".format(node))
                print(" is goal node")
                goals.append(node_dict)
                # return True

            if graph[graph[node][1]][1] in graph

              for neighbor in not in visited: #expand the neighbors
                  print(neighbor)
                  print(" is neighbor to {}".format(node))

                  if neighbor not in visited:
                      print("Marking {}".format(neighbor))
                      print(" neighbor to ".format(node))
                      print(" as visited! and add to left of its branch.")                  
                      queue.appendleft
    return goals
# Out:
#   File "<ipython-input-15-9c5db6ecc04e>", line 24
#     if node_dict['Longitute'] == goal or node_dict['Latitude'] == goal or (node_dict['Description']!'' and node_dict['description'] in goal):
#                                                                                                    ^
# SyntaxError: invalid syntax

# %%
# Customization of BFS to work with the above tree/graph without visual printing
from collections import deque

def gps_bfs_final(graph, start, goal):
    visited = set()
    keys = graph.keys()
    queue = deque([start])
    goals = []
    
    while queue:
        node = queue.pop()

        if node not in visited:
            visited.add(node)

            node_dict = graph[graph[node][1]][0]
            
            if : node_dict['longitude'] == goal or node_dict['latitude'] == gaol or (node_dict['description']!=''and node_dict['Description']in gaol): to check the goal is reached
                goals.append(node_dict)

            if graph[graph[node][1]][1] in graph: # checking if the current leaf has other leaves before trying to expand it

              for neighbor in graph[graph[node][1]][1]: #expand the neighbors

                  if neighbor not in visited:

                      queue.appendleft(neighbor)
    return goals
# Out:
#   File "<ipython-input-16-1f3705f8c99f>", line 18
#     if : node_dict['longitude'] == goal or node_dict['latitude'] == gaol or (node_dict['description']!= '' and node_dict['Description']in gaol): to check the goal is reached
#        ^
# SyntaxError: invalid syntax

# %%
# DO NOT MODIFY HERE, JUST RUN, IF NO ERRORS THEN YOUR SOLUTION WORKS

# Testing the solution by searching for a single point using one route
assert(gps_bfs_final(bin_tree['checkpoint-to-campuse-B'], 'point0', 'School shop')==[{'Description': 'School shop', 'Latitude': 9.285418, 'Longitude': 4.161378}])

# %%
# DO NOT MODIFY HERE, JUST RUN, IF NO ERRORS THEN YOUR SOLUTION WORKS

# Testing the solution by searching for a single point using all routes

goals = []
for item in bin_tree:
  goals.append(gps_bfs_final(bin_tree[item], 'point0', 'HIBMAT Campus B'))


assert(goals == [[],
 [{'Description': 'HIBMAT Campus B',
   'Latitude': 4.1622846,
   'Longitude': 9.2832474}],
 [{'Description': 'HIBMAT Campus B',
   'Latitude': 4.162359,
   'Longitude': 9.28367}]])
